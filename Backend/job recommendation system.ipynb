# %%
import numpy as np
import pandas as pd

# %%
job_df = pd.read_csv("Combined_Jobs_Final.csv")

# %%
job_df.head(2)
# Out:
#    Job.ID  Provider Status                                             Slug  \
# 0     111         1   open                  palo-alto-ca-tacolicious-server
# 1     113         1   open  san-francisco-ca-claude-lane-kitchen-staff-chef
#
#                               Title            Position      Company  \
# 0              Server @ Tacolicious              Server  Tacolicious
# 1  Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef  Claude Lane
#
#             City  State.Name State.Code  ...            Industry  \
# 0      Palo Alto  California         CA  ...  Food and Beverages
# 1  San Francisco  California         CA  ...  Food and Beverages
#
#                                      Job.Description  Requirements Salary  \
# 0  Tacolicious' first Palo Alto store just opened...           NaN    8.0
# 1   \r\n\r\nNew French Brasserie in S.F. Financia...           NaN    0.0
#
#   Listing.Start  Listing.End  Employment.Type Education.Required  \
# 0           NaN          NaN        Part-Time                NaN
# 1           NaN          NaN        Part-Time                NaN
#
#                 Created.At               Updated.At
# 0  2013-03-12 02:08:28 UTC  2014-08-16 15:35:36 UTC
# 1  2013-04-12 08:36:36 UTC  2014-08-16 15:35:36 UTC
#
# [2 rows x 23 columns]

# %%
print(len(job_df))
job_df = job_df[['Status', 'Title', 'Position', 'Company', 'Job.Description']]
print(len(job_df))
# Out:
# 84090
# 84090

# %%
job_df.shape
# Out:
# (84090, 5)

# %%
job_df['Job.Description'][20]
# Out:
# 'Hiring Event Details\r\nStore Associate\r\n\r\n$12.00 / Hour\r\nAdditional $1.00 Per Hour For ALL Sunday Shifts!\r\n50 Cent Wage Increases Beginning At 6 Months - Up to $13.50 At 2 Years\r\n\r\nMonday, December 15, 2014\r\n9am - 11am\r\n\r\nALDI\r\n3133 Market Place Dr\r\nOnalaska, WI 54650\r\n\r\n&nbsp;\r\nFor consideration, please apply in person at the hiring event only. Get started now by downloading our Store Employment Application.\r\n\r\nStore Associate - Retail Sales ( Customer Service )\r\n\r\nIf you are a customer service minded individual with a positive and energetic personality and you&rsquo;re interested in working for one of the best-known grocery stores in the nation, join the ALDI family! We are looking for motivated and reliable individuals to serve as a Store Associate. You will serve as the face of ALDI, providing customers with friendly and efficient check-out services. But that&rsquo;s just the beginning. You will also assist the store manager in a variety of roles, from stocking and merchandising our products to monitoring inventory and keeping the store looking clean and inviting. This is also an excellent ground-floor opportunity for you if you are interested in pursuing a management career, as we prefer to promote from within whenever possible. If you are a people person who likes to roll up your sleeves and put in a good day&rsquo;s work, we want to talk with you!\r\n\r\n\r\nStore Associate - Retail Sales ( Customer Service )\r\n\r\nJob Responsibilities\r\n&nbsp;\r\nAs a Store Associate, you will be involved in all aspects of keeping the store looking and functioning at its best. First and foremost, of course, you will keep your checkout line moving as quickly and smoothly as possible while ensuring that customers have a pleasant and positive shopping experience. In addition, you will have a variety of other duties throughout the store, which you will perform on an as-needed basis.\r\n&nbsp;\r\nYour specific duties as a Store Associate will include:\r\n&nbsp;\r\n\r\n    \r\n    Providing friendly and informative customer service\r\n    \r\n    Ringing up customers quickly, efficiently, and with a smile\r\n    \r\n    Maintaining professional appearance and demeanor at all times\r\n    \r\n    Making a positive impression on customers to encourage word-of-mouth referrals\r\n    \r\n    Scanning products\r\n    \r\n    Conducting cash and inventory control\r\n    \r\n    Maintaining displays and ensuring that they are kept stocked and up to company standards\r\n    \r\n    Loading and unloading delivery trucks\r\n    \r\n    Rotating stock\r\n    \r\n    Keeping the store clean (floors, registers, bathrooms, etc.)\r\n\r\n'

# %%
job_df.isnull().sum()
job_df.fillna('',inplace=True)
job_df.isnull().sum()
# Out:
# Status             0
# Title              0
# Position           0
# Company            0
# Job.Description    0
# dtype: int64

# %%
job_df = job_df.sample(n=1000,random_state=42)

# %%
job_df.shape
# Out:
# (1000, 5)

# %% [markdown]
# # cleaning dataset
# keeping all letters and digits
# lover case
# removing stopwords
# tokenization
# stemming

# %%
from nltk.corpus import stopwords
# import nltk
import re
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
# nltk.download('punkt')
# nltk.download('stopwords')
# print(nltk.data.find('tokenizers/punkt'))
# nltk.data.path.append('/Users/chiraglokhande/nltk_data')

import spacy

nlp = spacy.load("en_core_web_sm")

# %%
# def cleaning(txt):
#     txt = re.sub(r'[^a-zA-Z0-9\s]', '', txt)
#     doc = nlp(txt.lower())
#     tokens = [token.text for token in doc]
#     stemming = [ps.stem(w) for w in tokens if w not in stopwords.words('english')]
#     # Return a single string instead of a list
#     return ' '.join(stemming)


def cleaning(txt):
    # Remove special characters, newline characters, and multiple spaces
    txt = re.sub(r'[^a-zA-Z0-9\s]', '', txt)  # Remove special characters
    txt = re.sub(r'[\r\n]+', ' ', txt)  # Replace newline characters with a space
    txt = re.sub(r'\s+', ' ', txt)  # Replace multiple spaces with a single space
    
    doc = nlp(txt.lower())  # Convert to lowercase and process text
    tokens = [token.text for token in doc]  # Tokenize the text
    
    # Apply stemming and remove stopwords
    stemming = [ps.stem(w) for w in tokens if w not in stopwords.words('english')]
    
    # Return a single string instead of a list
    return ' '.join(stemming)

# %%
cleaning("\n\rhelo the master piece is my loving moving cat @9032#%$")
# Out:
# '  helo master piec love move cat 9032'

# %%
job_df['Job.Description'] = job_df['Job.Description'].astype(str).apply(lambda x: cleaning(x))
job_df['Title'] = job_df['Title'].astype(str).apply(lambda x: cleaning(x))
job_df['Position'] = job_df['Position'].astype(str).apply(lambda x: cleaning(x))

# %%
job_df['clean_text'] = job_df['Job.Description']+" "+job_df['Title']+job_df['Position']

# %%
job_df['clean_text'][64119]
# Out:
# 'job summari knowledg univers ku site director site leader inspir children teacher alik learn grow passion educ excel confid teach children adult use nation recogn curriculum framework creat uniqu engag classroom experi commit make site success know meaning relationship children famili team import success fulli engag enthusiast work eager share knowledg other job respons essenti function basic expect site director cours creativ new way meet exceed expect encourag long requir essenti function also met supervis children staff record keep licens record child file lesson plan implement mainten safe welcom classroom environ build relationship commun school recruit new student program applic must strong organiz skill site director knowledg universsite director'

# %% [markdown]
# # vectorizatoin

# %%
job_df['combined_text'] = job_df['Title'] + " " + job_df['Position'] + " " + job_df['Company'] + "" +job_df['clean_text'] 
 
job_df['combined_text'][64119]
# Out:
# 'site director knowledg univers site director Knowledge Universejob summari knowledg univers ku site director site leader inspir children teacher alik learn grow passion educ excel confid teach children adult use nation recogn curriculum framework creat uniqu engag classroom experi commit make site success know meaning relationship children famili team import success fulli engag enthusiast work eager share knowledg other job respons essenti function basic expect site director cours creativ new way meet exceed expect encourag long requir essenti function also met supervis children staff record keep licens record child file lesson plan implement mainten safe welcom classroom environ build relationship commun school recruit new student program applic must strong organiz skill site director knowledg universsite director'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# tfidf = TfidfVectorizer(stop_words='english')
# matrix = tfidf.fit_transform(job_df['clean_text'])
# similarity = cosine_similarity(matrix)

tfidf = TfidfVectorizer(stop_words='english')

# Fit and transform the cleaned text
matrix = tfidf.fit_transform(job_df['combined_text'])

# Compute the cosine similarity matrix
similarity = cosine_similarity(matrix)

# %%
similarity
# Out:
# array([[1.        , 0.03750839, 0.01579204, ..., 0.04718412, 0.01708843,
#         0.06612123],
#        [0.03750839, 1.        , 0.02408708, ..., 0.03279808, 0.00478697,
#         0.02723048],
#        [0.01579204, 0.02408708, 1.        , ..., 0.04443238, 0.02996735,
#         0.04040011],
#        ...,
#        [0.04718412, 0.03279808, 0.04443238, ..., 1.        , 0.05217026,
#         0.09961131],
#        [0.01708843, 0.00478697, 0.02996735, ..., 0.05217026, 1.        ,
#         0.37446873],
#        [0.06612123, 0.02723048, 0.04040011, ..., 0.09961131, 0.37446873,
#         1.        ]])

# %%
sorted(list(enumerate(similarity[0])), key=lambda x: x[1], reverse=True)[1:20]
# Out:
# [(276, np.float64(0.9484782708382822)),
#  (730, np.float64(0.4614697501291734)),
#  (81, np.float64(0.4291312793015668)),
#  (917, np.float64(0.4291312793015668)),
#  (252, np.float64(0.26058581908840395)),
#  (629, np.float64(0.23188313365483862)),
#  (825, np.float64(0.2072347239225912)),
#  (360, np.float64(0.20405678270391356)),
#  (128, np.float64(0.19600885831079434)),
#  (38, np.float64(0.19323954080632813)),
#  (982, np.float64(0.16772644271462298)),
#  (114, np.float64(0.16414592987038637)),
#  (298, np.float64(0.15197869520452675)),
#  (847, np.float64(0.14371085721904345)),
#  (245, np.float64(0.13953676434226892)),
#  (113, np.float64(0.13463028202009936)),
#  (254, np.float64(0.13445659698301712)),
#  (59, np.float64(0.1326890672201081)),
#  (528, np.float64(0.12496696461467746))]

# %% [markdown]
# # Recommendation System

# %%
job_df
# Out:
#       Status                                              Title  \
# 64119   open                     site director knowledg univers
# 35827   open                        administr assist officeteam
# 72100   open                   account manag chi payment system
# 46355   open  outsid wholesal sale rep parttim river front c...
# 34166   open  custom servic rep help peopl hear loss captioncal
# ...      ...                                                ...
# 66282   open  sale repres sale associ entri level vector market
# 39515   open                           staff account accountemp
# 69231   open                  unarm secur offic us secur associ
# 69618   open            line cook crown plaza independ own oper
# 6144    open  kitchen manag job detail artesian hotel casino...
#
#                                      Position  \
# 64119                           site director
# 35827                        administr assist
# 72100                           account manag
# 46355        outsid wholesal sale rep parttim
# 34166  custom servic rep help peopl hear loss
# ...                                       ...
# 66282     sale repres sale associ entri level
# 39515                           staff account
# 69231                       unarm secur offic
# 69618                               line cook
# 6144                 kitchen manag job detail
#
#                                                  Company  \
# 64119                                 Knowledge Universe
# 35827                                         OfficeTeam
# 72100                                CHI Payment Systems
# 46355                    River Front Chrysler Jeep Dodge
# 34166                                        CaptionCall
# ...                                                  ...
# 66282                                   Vector Marketing
# 39515                                        Accountemps
# 69231                             US Security Associates
# 69618       Crowne Plaza- Independently Owned & Operated
# 6144   The Artesian Hotel and Casino - Tradition Spirits
#
#                                          Job.Description  \
# 64119  job summari knowledg univers ku site director ...
# 35827  ref 03110118480classif secretaryadmin asstcomp...
# 72100  yoursquor energet motiv hardwork look prosper ...
# 46355  outsid wholesal sale rep job respons sale repr...
# 34166    captioncal commun assist imagin life without...
# ...                                                  ...
# 66282    nbsp eager learn opportun whether look partt...
# 39515  ref id02120107460classificationaccount staffco...
# 69231  direct supervis unarm secur offic respons patr...
# 69618  summari respons maintain set food product qual...
# 6144   posit descript provid overal leadership superv...
#
#                                               clean_text  \
# 64119  job summari knowledg univers ku site director ...
# 35827  ref 03110118480classif secretaryadmin asstcomp...
# 72100  yoursquor energet motiv hardwork look prosper ...
# 46355  outsid wholesal sale rep job respons sale repr...
# 34166    captioncal commun assist imagin life without...
# ...                                                  ...
# 66282    nbsp eager learn opportun whether look partt...
# 39515  ref id02120107460classificationaccount staffco...
# 69231  direct supervis unarm secur offic respons patr...
# 69618  summari respons maintain set food product qual...
# 6144   posit descript provid overal leadership superv...
#
#                                            combined_text
# 64119  site director knowledg univers site director K...
# 35827  administr assist officeteam administr assist O...
# 72100  account manag chi payment system account manag...
# 46355  outsid wholesal sale rep parttim river front c...
# 34166  custom servic rep help peopl hear loss caption...
# ...                                                  ...
# 66282  sale repres sale associ entri level vector mar...
# 39515  staff account accountemp staff account Account...
# 69231  unarm secur offic us secur associ unarm secur ...
# 69618  line cook crown plaza independ own oper line c...
# 6144   kitchen manag job detail artesian hotel casino...
#
# [1000 rows x 7 columns]

# %%
print(job_df['Title'].unique())
# Out:
# ['site director knowledg univers' 'administr assist officeteam'
#  'account manag chi payment system'
#  'outsid wholesal sale rep parttim river front chrysler jeep dodg'
#  'custom servic rep help peopl hear loss captioncal' 'bookkeep accountemp'
#  'nuclear medicin tech prn hcaeast florida'
#  'construct project admin need asap officeteam' 'account clerk accountemp'
#  'cashier murphi usa'
#  'caregiv home health aid cna home instead senior care'
#  'hha cna need immedi bayada home health care'
#  'oto sale advisor 224 twinsburg club demonstr servic'
#  'behavior health nurs bhn mission healthcar servic inc'
#  'recent gradsaccount financ accountemp'
#  'custom servic repres sale experi prefer officeteam'
#  'market sale repres weed man usa franchis'
#  'staff account emerg softwar compani accountemp'
#  'warehous stocker restaur depot'
#  'automot titl support clerk part time jack cooper transport'
#  'lpn oakview rehab nurs center'
#  'oto culinari ambassador 39 washington club demonstr servic'
#  'lm administr officeteam' 'assist district manag gannett co inc'
#  'offic assist officeteam'
#  'pharmacist clinic specialist ltc parttim day shift flexibl hr swedish health'
#  'data entri clerk officeteam'
#  'sale repres sale associ entri level vector market'
#  'receptionist healthcar compani n houston officeteam'
#  'hospitali ambassador part time digniti heath sequoia hospit'
#  'temporari audit rn ut southwestern'
#  'privat tutor talent tutor need immedi varsiti tutor'
#  'restaur hourli team member dishwash line cook self opportun'
#  'occup therapist ot' 'bill clerk accountemp' 'regist nurs pressley ridg'
#  'fellowship program coordin connecticut children medic center'
#  'market assist officeteam' 'groundskeep season part time east fork cross'
#  'driver labor readi gener labor job'
#  'surgic technologist surgeri 2 fte variabl shift swedish health'
#  'nurs lpn rn miller merri manor'
#  'store manag traine fireston complet auto care'
#  'assist server busser restaur crown plaza independ own oper'
#  'season loss prevent secur guard newark ca newpark mall maci'
#  'full cycl account payabl clerk accountemp' 'budget analyst accountemp'
#  'new account open offic accountemp'
#  'activ assist hotel resort custom servic retail sun commun'
#  'flex offic securita usa' 'data entri specialist accountemp'
#  'account clerk cobleskil ny holiday inn independ own oper'
#  'librari associ denison univers'
#  'administr assist need immedi officeteam' 'rnphn area 12 agenc age'
#  'season csr david bridal' 'secur offic 100000 job coalit securita usa'
#  'retail sale manag opportun sofa mart oak express bedroom express furnitur row'
#  'part time retail merchandis drivelin retail'
#  'receivingstock associ herberg'
#  'receptionistscheduleroper north clinic merci medic center pt 5 vari cathol health initi'
#  'sale repres retail art van furnitur'
#  'dock worker loader southeastern freight line' 'bill associ accountemp'
#  'schoolbas speech therapist commun rehab associ inc'
#  'head housekeep holiday inn express independ own oper'
#  'respa specialist accountemp'
#  'west la busi seek temp hire bookkeep accountemp'
#  'retail cosmet sale beauti advisor clarin part time wayn nj maci willowbrook maci'
#  'buyer purchas accountemp' 'assist manag dollar tree store'
#  'parttim commerci properti manag bookkeep account american exterior solut'
#  'staff account alway need accountemp' 'job fair platinum health care'
#  'staff accountantdeltek costpoint accountemp'
#  'sale counselor new luxuri senior livingcarmel justu rental properti'
#  'associ pharmaci servic deliveri driver 20 hour per week cardin health'
#  'assist teacher knowledg univers'
#  'per diem home health aid 140198 gentiva health servic inc'
#  'benefit administr long term contract accountemp'
#  'temporari human resourc generalist officeteam'
#  'express lube technician mister car wash'
#  'pt digit produc gannett co inc' 'school bu driver first student'
#  'retail sale associ part time marketsourc' 'tax prepar accountemp'
#  'account payabl specialist team inc'
#  'gener offic clerk131450hr officeteam' 'cdl labor hulcher servic'
#  'part time part clerk industri air center inc iac'
#  'event specialist part time advantag sale market'
#  'credenti specialist officeteam' 'shoe sale associ base commiss herberg'
#  'sale assist officeteam' 'project assist blue ash officeteam'
#  'blow mold oper callo resourc'
#  'call center repres parttim charl foster compani'
#  'assist manag fred super dollar'
#  'staff account need grow compani accountemp'
#  'account payabl clerk accountemp'
#  'di special servic brand ambassador wilmington market club demonstr servic'
#  'payrol administr sheridan plumb sewer'
#  'center custom servic specialist need officeteam'
#  'administr secretari digniti health commun hospit san bernardino'
#  'arm secur offic securita usa'
#  'youth camp residenti assist activ coordin new york ny el educ servic'
#  'emerg medic technician emt bartlett region hospit'
#  'paramed hampton road va american medic respons'
#  'product placement specialistseason part time northern tool'
#  'sale associ dufresn spencer group ashley furnitur'
#  'custom servic repres officeteam' 'premium auditor nei inc'
#  'direct care ftptsub shift avail commun option inc'
#  'regist nurs ed per diem shift vari barstow healthcar mgmt mso'
#  'regist nurs rn icupt nightskindr hospit kansa citymo64131 kindr healthcar'
#  'kool smile hygienist part time fridayssaturday kool smile'
#  'payrol human resourc specialist accountemp'
#  'immedi open assist teacher la petit academi'
#  'warehous data entri clerk neeed asap officeteam'
#  'immedi needaccount payabl clerk columbu accountemp'
#  'merchandis part time midland tx am retail solut'
#  'part time interior design associ lazboy'
#  'k12 test evalu need score elementaryhigh school test kelli servic inc'
#  'sale associ sale consult bob discount furnitur'
#  'connect intern bayada home health care'
#  'entri level posit open new officeshir immedi appli today'
#  'recreat therapist harbor oak hospit'
#  'shoe sale associ base commiss younker'
#  'public staff tax account accountemp'
#  'hire restaur posit server cook bartend oliv garden'
#  '175 hr teller internant ce well fargo' 'sale consult primari servic'
#  'lpn coventri meadow assist live memori care garden home'
#  'cookdietari aid miller merri manor'
#  'transport secur offic transport secur administr' 'pharmacist confidenti'
#  'staff account accountemp'
#  'custom servic sale new grad welcom vector market'
#  'bookkeep odessa need asap accountemp' 'ship receiv thetouringstorecom'
#  'mathemat parttim faculti noncredit commun colleg philadelphia'
#  'insur inspector transtar technic servic' 'dentist dd dmd dental dream'
#  'licens practic nurs lpnlvn healthcar lpnlvn nurs evangel lutheran good samaritan societi'
#  'assist vice presid financi servic sale dunbar armor'
#  'retail project merchandis advantag sale market'
#  'offic profession syracus new york rochest central new york associ thrivent financi'
#  'privat tutor 5060 talent tutor need immedi varsiti tutor'
#  'account repres att solut provid confidenti'
#  'secur officercorrect st moritz secur servic inc'
#  'mech engin intern hargrov engin constructor'
#  'season retail fit room associ sugar land tx first coloni maci'
#  'account receiv specialist w hospit experi accountemp'
#  'selector part time dpi specialti food'
#  'regist nurs telephon triag part time swedish health'
#  'junior recruit posit officeteam'
#  'colleg student look parttim work look officeteam' 'server commi'
#  'account manag supervisor accountemp'
#  'front desk coordin innov softwar develop officeteam'
#  'receptionist officeteam'
#  'account receiv clerk fast pace startup accountemp'
#  'senior sustain coordin department assist auxiliari enterpris univers massachusett amherst'
#  'oil ga schedul need immedi accountemp'
#  'social worker behavior health per diem hcaeast florida'
#  'account receiv clerk accountemp' 'account payabl specialist accountemp'
#  'housekeep brookdal'
#  'certifi medic asst parttimeweekend 1820hr erickson live'
#  'hire kitchen posit line prep cook dishwash longhorn steakhous'
#  'market commun oper intern parttim hewlettpackard'
#  'human resourc assist officeteam'
#  'commerci collect specialist accountemp'
#  'certifi home health aidecna caresouth' 'faculti call zenith educ group'
#  'valet park attend gsa quinci il town park'
#  'data warehous developerbi develop'
#  'medic technologist 32 hour week even provid health servic'
#  'clerk funer detail servic corpor intern' 'restaur manag oliv garden'
#  'lifeguard balfour beatti invest'
#  'certifi nurs assist cna transit care unit provid health servic'
#  'season retail sell floor recoveri earli 11 houston tx houston galleria hidalgo maci'
#  'entri level sale custom servic part time full time vector market'
#  'patient servic repres midwest dental'
#  'licens practic nurs lpn home care monro north carolina bayada home health care'
#  'truck driver cdl class atouch freight pensk logist pensk'
#  'retail sale associ showroom sale interior design consult art van furnitur'
#  'contract recruitersouth counti officeteam'
#  'part time bookkeep stiver staf talent network'
#  'licens practic nurs lpn pediatr bayada home health care'
#  'part time home servic provid rep american residenti servic'
#  'licens vocat nurs hospic part time variabl shift provid health servic'
#  'sourcerrecruit work home officeteam'
#  'data entri clerk even knowledg servic' 'agenc pharmacist christu health'
#  'gener offic clerk officeteam' 'season merchandis associ spectrum brand'
#  'part time faculti ana g mendez univers system'
#  'person care aid assist live brightview senior live'
#  'retail merchandis specialist sa retail servic'
#  'admin assist need medic leav spring grove officeteam'
#  'payrollhrap administr need brentwood accountemp'
#  'account payabl accountemp'
#  'adjunct faculti job fair northern virginia commun colleg'
#  'releas inform specialist healthport'
#  'speech languag pathologist visit nurs servic connecticut'
#  'automot servic advisor custom servic ta petro'
#  'pediatr nurs need quakertown pa bayada home health care'
#  'bill clerk ledgent financ account'
#  '1st 2nd shift gener labor need immedi kelli servic'
#  'part time mainten sovran self storag inc'
#  'custom servic rep zion bancorpor california bank trust'
#  'rn lpn need pediatr bayada home health care'
#  'event specialist part time sale advantag sale market'
#  'loan processor need sf accountemp'
#  'medic offic assist instructor concord career colleg inc'
#  'parttim food servic specialist devereux'
#  'deliveri driver part time ankeni iowa napa'
#  'staff account move quickli accountemp'
#  'retail specialist season advantag sale market'
#  'social worker msw home health provid health servic'
#  'cook knowledg univers' 'continu improv intern generac'
#  'pharmaci adjunct instructor brown macki colleg'
#  'hvac career train local heat air condit refriger train avail hvac career'
#  'manufactur staff account accountemp'
#  'day program commun access mentor unit cerebr palsi georgia'
#  'hotel valet park attend northern va town park' 'rn lock hospit'
#  'callseason teller bruswick keybank' 'deliveri driver part time job napa'
#  'physic therapi assist pta brookdal'
#  'secur offic unarm secur offic secur guard andi frain servic'
#  'amaz opportun recruit officeteam'
#  'certifi home health aid cna bayada home health care'
#  'vietnames interpret translat languagelin solut'
#  'hourli posit hobbi lobbi store inc' 'commun sale rep marketsourc'
#  'loan intak associ officeteam' 'sale rep verizon fio big box'
#  'physic therapist transit care center swedish health'
#  'parttim account assist accountemp'
#  'housekeep commonwealth assist live llc'
#  'site director knowledg univers educ llc'
#  'live home health aid hha immedi need shift 7 sat 7 monday home hospit medic personnel inc'
#  'ap clerk accountemp' 'gener dutytransit job servic corpor intern'
#  'sale merchandis specialist coworx staf servic'
#  'account payabl coordin dougla autotech corpor'
#  'market commun assist tmg' 'faculti support specialist zenith educ group'
#  'warehous driver urgent need publish circul fulfil'
#  'financi analyst accountemp' 'pediatr nurs confidenti'
#  'cna consul health care'
#  'regist nurs rn licens practic nurs lpn healthcar nurs staff evangel lutheran good samaritan societi'
#  'volkswagen lot porter sheehi auto store'
#  'immedi open account payabl assist piqua accountemp'
#  'chaplain resid facil sjmh hospit ann arbor locat ann arbor mi st joseph merci ann arbor'
#  'culinari art chef career train local culinari train avail chef career'
#  'merchandis processor leetsdal retail store goodwil industri denver'
#  'insid sale rep need grow compani cincinnati officeteam'
#  'emerg dept charg analyst per diem hcaeast florida'
#  'secur offic regular securita usa'
#  'assist retail store manag ft pt vitamin world inc'
#  'sale associ play sport' 'medic bill specialist accountemp'
#  'front offic secretari medic assist confidenti'
#  'person banker shadysid fcparttim fifth third bank'
#  'per diem critic care clinic consult self opportun'
#  'multitask custom servic repres need officeteam'
#  'crew member goodcent deli fresh sub' 'front desk coordin officeteam'
#  'store clerk ruler food' 'data analyst accountemp'
#  'retail sale specialist parttim job time warner cabl'
#  'retail sale repres tmobil'
#  'faculti ii degre crimin justic linear program everest colleg'
#  'per diem alli medic assist alli medic assist parallon workforc solut'
#  'surgic tech prn scch mountain state health allianc'
#  'men design sell specialist full timepart time bloomingdal newport beach ca bloomingdal'
#  'bellman hilton grand rapid marriott intern'
#  'connect maci specialist part time atlanta ga maci lenox squar maci'
#  'small engin mechan altaquip'
#  'search motiv bilingu receptionist officeteam'
#  'rnnicu parttim night tombal region medic center'
#  'stna hillandal famili commun'
#  'patient serv rep onsit es firstsourc solut ltd' 'storeassoc stock napa'
#  'viticultur intern constel brand inc'
#  'mechan career train local auto diesel mechan train avail mechan career'
#  'connect maci coordin part time buford ga maci mall georgia maci'
#  'retail sale associ art van furnitur'
#  'charg licens practic nurs lpn healthcar charg lpn nurs evangel lutheran good samaritan societi'
#  'custom servic repres insur compani columbu officeteam'
#  'dock worker pt night new penn' 'occup therapist provid health servic'
#  'tabletcapsul machin oper ultim staf servic'
#  'cna certifi nurs assist pediatr bayada home health care'
#  'assist manag sale supervisor spencer gift'
#  'instructor clinic vn rn american career colleg'
#  'human resourc generalist degre requir officeteam'
#  'part time school bu driver want train avail student transport america inc'
#  'member servic repres parttim mesa navi feder credit union'
#  'regist nurs rn home care pool vita healthcar'
#  'maci season cosmet beauti advisor fredricksburg va spotsylvania town center maci'
#  'tax account accountemp'
#  'social servic job fair tue mar24th 4pm6pm yai nation institut peopl disabl'
#  'truck driver hiker vehicl transportercdl part time pensk'
#  'superintend cqmcqc manag construct labor contractor'
#  'rn staff prn lo robl surgeri center parallon'
#  'part time retail merchadis drivelin retail'
#  'merchandis sa retail servic' 'regist nurs greater cincinnati pain mgmt'
#  'account manag sale' 'summer school age assist children courtyard'
#  'target mobil sale associ marketsourc' 'senior sale associ music art'
#  'sale support representativepart time att retail'
#  'part time pharmacist cincinnati oh genoa qol healthcar'
#  'recoveri specialist behavior health adult unit parttimeeven cathol health initi'
#  'transport assist parttim appleton apf gannett co inc'
#  'properti manag intern raleigh nc midamerica apart commun'
#  'hire event secur offic spot interview riversid univers protect servic'
#  'custom servic opportun sale immedi open alorica'
#  'receivingstock associ younker' 'colleg intern sale oper hewlettpackard'
#  'home health physic therapist per diem humana'
#  'housekeep crown plaza independ own oper'
#  'temporari driver lead ground deliveri compani randstad profession'
#  'prn iii medicalsurg regist nurs heartland region medic center'
#  'qualiti control inspector' 'regist nurs agenc christu health'
#  'restaur manag moe southwest grill'
#  'entri level sale repres chi payment system'
#  'rn regist nurs med surg tele per diem night woodland healthcar'
#  'rn emerg room prn nightmed center christu health'
#  'rn lpn pediatr home care bayada home health care'
#  'certifi nurs assist manor novi' 'season wed sale stylist david bridal'
#  'appoint settersearn 400800 per week parttime1000 per week fulltim sm'
#  'di sale advisor club demonstr servic'
#  'cna need plant citi area bayada home health care'
#  'wm recycl corp internship program pacif northwest wast manag inc'
#  'intervent specialist aspiranet'
#  'medic insur claim specialist accountemp'
#  'certifi nurs assist pt night benefit med surg ucmh mountain state health allianc'
#  'commun engag coordin nation multipl sclerosi societi'
#  'custom entri writer officeteam'
#  'lead valet park attend philadelphia pa town park'
#  'receptionist part time 5 hour per week need health integr'
#  'home care nurs need chalfont pa bayada home health care'
#  'administr assist long term potenti officeteam'
#  'dedic part time bookkeep need small og compani accountemp'
#  'med receptionist ii parttim even weekend swedish health'
#  'retail sale associ key holder destin xl group'
#  'activ assist hotel resort custom servic sun commun'
#  'want execut assist officeteam'
#  'counter sale traine retail high point winstonsalem greensboro napa'
#  'groundskeep bell partner inc' 'leas agent'
#  'cna certifi nurs assist hha home health aid sellersvil pa bayada home health care'
#  'oto sale advisor 440 south euclid club demonstr servic'
#  'event market retail market' 'loan serviceradministr accountemp'
#  'retail sale associ parttim'
#  'revenu account need midland texa accountemp'
#  'medic account receiv specialist accountemp'
#  'physician assist armor correct health servic'
#  'veterinari technicianassist west michigan street veterinari clinic'
#  'medic assist prn 236615005 concentra' 'dcassoc stockroomparttim napa'
#  'account clerk need west la bank accountemp'
#  'physic therapist pt mission healthcar servic inc'
#  'season event planner multipl open westfield insur'
#  'home store sale profession full timepart time bloomingdal walt whitman shop ny maci'
#  'bill repres accountemp' 'lube technician jiffi lube'
#  'retail sale merchandis part time advantag sale market'
#  'teller custom servic parttim ft lauderdal branch space coast credit union'
#  'retail reset merchandis part time advantag sale market'
#  'parttim victim servic specialist 01815 mother drunk drive madd'
#  'human resourc assist need today officeteam'
#  'account entri level accountemp' 'regist nurs part time amedisi'
#  'pcahuc ulhneuro icu parttim night kentuckyon health'
#  'lab assist call whc woodland healthcar'
#  'part time return agent indianapoli airport nationalalamo'
#  'vascular technician swedish health' 'human resourc assist 12 officeteam'
#  'pediatr rn lpn trach bayada home health care' 'data entri officeteam'
#  'full charg bookkeep accountemp'
#  'bilingu human resourc recruit officeteam'
#  'certifi nurs assistantshom health aidespati care associ cnashhaspca privatu care solut inc'
#  'clinic nurs rn prn consul health care'
#  'maci season retail sale maci appoint holiday shopper full timepart time walnut creek ca broadway plaza maci'
#  'sale associ springfield campbel 8482 sherwinwilliam compani'
#  'lifeguardsinstructor desert recreat district'
#  'rnlpn pediatr home care love care agenc'
#  'direct care group home residenti assist easter seal rehabilit center'
#  'php develop x2 consultnet' 'imag verifi faneuil'
#  'pt branch offic administratormount joy pabranch 64525 edward jone boa'
#  'trade support analyst accountemp'
#  'member servic rep traine lo angel dj recruitng servic'
#  'secur guard act retir life commun'
#  'design bed sell specialist full timepart time bloomingdal mall short hill nj maci'
#  'home care aid wesleylif ame wesleylif'
#  'season deliveri driver class cdlhazmat blue rhino'
#  'senior servic representativept 38bartlett bmo harri bank'
#  'cashier part time northern tool'
#  'food servic associ ii part time wben mountain state health allianc'
#  'block clerk cox automot inc'
#  'breakfast attend weekend holiday inn express independ own oper'
#  'student servic repres new horizon comput learn center'
#  'bereav manag vita innov hospic care'
#  'retail sale associ parttim marketsourc' 'nurs lpn devereux'
#  'senior custom servic regu express regu manag group'
#  'dine room server parttim prestig care inc'
#  'retail cosmet sale beauti advisor lancom part time woodland tx maci woodland maci'
#  'lpn rn pca home health profession case manag'
#  'retail support price team lead part time burlington maci burlington mall maci'
#  'compens team member officeteam'
#  'oto sale advisor 62 rochest club demonstr servic'
#  'offic assist part time 9am2pm mf downtown locat officeteam'
#  'execut assist officeteam'
#  'regist nurs rn assist live evangel lutheran good samaritan societi'
#  'enrol agent immedi opportun officeteam'
#  'night auditorpart time great wolf lodg wi'
#  'oper clerkparttimeup freight up'
#  'regist nurs rn home health nurs healthcar partner home'
#  'custom servic supervisor result driven role officeteam'
#  'seek 2 insid sale support member officeteam'
#  'custom servic representativesal associ speedway llc'
#  'custom care associ eastbayinc'
#  'front desk hr admin priorityworkforc inc'
#  'part time custom servic repres check n go'
#  'clinic nurs rn consul health care'
#  'pt therapist newport news juvenil drug court hamptonnewport news commun servic board'
#  'immedi need sale assist officeteam'
#  'technolog sale specialist marketsourc'
#  'ptft bhi counselor 2635 hour sequel youth famili servic'
#  'night nurs need home care bayada home health care'
#  'veterinari assistanttechnician phoenix vet hospit'
#  'part time sale green drop lawn care'
#  'cashier whc temporari oncal woodland healthcar'
#  'gener laborwarehous 84 lumber'
#  'teller intern lee summit nation bank kansa citi' 'dispatch securita usa'
#  'gener offic clerk opportun officeteam'
#  'parttim teller downtown hamilton keybank'
#  'rental sale agent commiss base nation newark airport nationalalamo'
#  'assist store manag retail servic part deliveri specialist oreilli auto part'
#  'dispatch officeteam' 'dietitian freseniu medic care'
#  'retail sale associ' 'lpn licens practic nurs bayada home health care'
#  'retail commiss sale women shoe part time la vega nv maci fashion show maci'
#  'medic assist certifi neurolog provid health servic'
#  'pharmaci technician part time full time fred meyer'
#  'care habilit technician direct support bayada home health care'
#  'receptionist westview nurs rehabilit center' 'enrol analyst officeteam'
#  'cashier posit longmont retail store goodwil industri denver'
#  'inventori analyst accountemp'
#  'market associ dietari supplement compani officeteam'
#  'regist nurs mcleod center' 'gener labor warehous lumber yard 84 lumber'
#  'occup therapist ot brookdal'
#  'behavior interventionist easter seal southern california'
#  'licens practic nurs lpn rescar'
#  'parttim person care attend 1920dunn gentiva health servic inc'
#  'secur offic mall sierra vista univers protect servic' 'dietitian'
#  'person trainer la fit' 'bookkeepergrow compani accountemp'
#  'custom sale advisor jiffi lube' 'medic bill claim specialist accountemp'
#  'lead gener paid hourli weed man usa franchis'
#  'di special servic brand ambassador market club demonstr servic'
#  'retail field repres marketsourc'
#  'execut assist temp entertain industri officeteam'
#  'mortgag analyst accountemp' 'nurs lpn rn lss home health care'
#  'vee quiva casino hire restaurantfoodcourt manag beverag manag supervisor server bartend ovat food servic'
#  'data entri clerk grow properti manag compani officeteam'
#  'certifi medic coder accountemp' 'tax review accountemp'
#  'driver cdl local dock entri level yrc freight'
#  'kool smile hygienist part time 23 daysweek kool smile'
#  'certifi home health aid chha bayada home health care'
#  'retail field repres part time sioux fall sd'
#  'mortgag underwrit accountemp'
#  'hire restaur posit server dishwash oliv garden'
#  'housekeep laundri assist evangel lutheran good samaritan societi'
#  'dockwork part time fedex freight'
#  'cnalpnrn opportun pleasant hill commun live center llc'
#  'dental assist medic assist familia dental'
#  'manag traine internsummerfairfielddanburynew ct enterpris rentacar'
#  'call center agent need even weekend dialamerica inc'
#  'retail brand proof manag' 'dishwash watermark immanuel campu care'
#  'regist nurs cardiac intervent christu spohn shorelin christu health'
#  'packag handler parttim up' 'houseperson pt mgm resort intern'
#  'unarm secur offic downtown phoenix avondal us secur associ'
#  'pharmaci technician connecticut children medic center'
#  'home care attend homemak care program casual digniti health merci hospit bakersfield'
#  'patient registr repres 05fteeven shift mill creek swedish health'
#  'secur offic unarm guardsmark llc' 'packag handler fedex ground'
#  'kitchen steward riverwood behavior health servic'
#  '  panera bread hourli associ product associ join us great opportun west market st louisvil panera bread'
#  '18hr incom potenti costco wireless sale expert wireless advoc'
#  'emi trust advisor 49 newark club demonstr servic'
#  'md coordin rn brookdal' 'brainerd part time preload supervisor up'
#  'account clerk puchas order experi want accountemp'
#  'account payabl clerk grow compani accountemp'
#  'custom servic rep need doral officeteam' 'project assist officeteam'
#  'regist nurs rn bayada home health care'
#  'senior execut assist spherion staf servic'
#  'maci season retail stock merchandis part time morn 5am2pm pembrok pine fl pembrok lake maci'
#  'home health nurs regist nurs caresouth'
#  'open hous april 22 season custom servic role officeteam'
#  'regist nurs prn home health medic servic america'
#  'temporari coordin site oper macyscom maci'
#  'part time produc clerk cari park town center harri teeter'
#  'physician autism center part time provid health servic'
#  'dock worker pt forward air inc' 'data entri clerk accountemp'
#  'parttim account receiv clerk parttim account payableinventori clerk stagnaro distribut'
#  'server waiter waitress wait staff oliv garden'
#  'callseason teller keybank'
#  'lpn primari nurs care manag commun health resourc'
#  'pediatr nurs home care pediatria healthcar kid'
#  'sale associ store 2941 mint hill nc sherwinwilliam compani'
#  'costco wireless sale expert wireless advoc'
#  'bookkeep flexibl work schedul accountemp'
#  'surgic tech iii cc pt w benefit ssh mountain state health allianc'
#  'vari account posit need accountemp'
#  'ephrata area purchasinginventori specialist accountemp'
#  'project employe data entri analyst hamilton nj navig consult inc'
#  'cdl truck driver deliveri driver transport copi us special deliveri'
#  'secur guard abc bank'
#  'women shoe sale profession part time bloomingdal 59th street nyc maci'
#  'medic administr officeteam' 'teller part time santand bank na'
#  'offic clerk immedi need officeteam'
#  'cna person home care aid pyramid home health servic'
#  'nurs rn lpn home care pfafftown nc bayada home health care'
#  'linehaul oper traine yrc freight'
#  'temporari dorm supervisor treasur island job corp'
#  'regist nurs officeteam' 'entri level account accountemp'
#  'maci season retail sell floor recoveri earli 11 west valley citi ut valley fair maci'
#  'front desk coordin reput financ organ officeteam'
#  'nurs medic assist phlebotomist need well screen quest diagnost'
#  'sale market retail repres bluegreen vacat' 'associ manag tumi inc'
#  'regist nurs renfrew center'
#  'pharmacistprn select medic long term acut care hospit'
#  'sale assistantbachelor degre requir officeteam'
#  'primari care physician volunt america nation servic'
#  'nurs vna prn reg 1 holi redeem'
#  'nurs career open hous cna rn lpn st ann commun'
#  'product employe mister car wash' 'collect specialist accountemp'
#  'shoe repair carl shoe'
#  'account servic financ repres part time adt secur servic inc'
#  'rn nurs weekend supervisor consul health care'
#  'occup therapist parttim consult children habilit center'
#  'part servic repres season part time northern tool'
#  'senior account accountemp' 'payrol clerk accountemp'
#  'cdl flatb driver trillium driver'
#  'sr custom assist repres iah enterpris rentacar'
#  'retail cosmet sale beauti advisor lancom part time melbourn fl maci melbourn squar maci'
#  'custom servic supervisor officeteam' 'youth counselor four oak'
#  'activ assist cardon associ'
#  'social worker msw home health swedish health'
#  'home health aid cna certifi nurs assist health home'
#  'receptionist even weekend merci rehabilit hospit springfield'
#  'direct care worker nh human servic'
#  'dept receptionistseci radiolog dept prn hcaeast florida'
#  'part time custom servic repres flexibl hour officeteam'
#  'regist nurs american profession associ' 'contract consult officeteam'
#  'commerci account manag orkin hirel'
#  'crematori oper servic corpor intern'
#  'custom servic repres need mason officeteam'
#  'part time sale associ lazboy'
#  'part time deliveri driver custom account rep self opportun'
#  'temporari lab aid tech 3rd shiftweekend vca antech diagnost'
#  'custom servic repres cj walsh group' 'oper coordin pt gannett co inc'
#  'invest oper associ need sf accountemp'
#  'regist nurs rn inpati rehab facil lehigh valley health network'
#  'admin assist cleric gold coast school' 'teacher knowledg univers'
#  'activ assist ltc pyramid point' 'appli behavior analysi therapist aba'
#  'craft parttim day shift mlk commun hospit'
#  'registr repres entri level immedi avail confidenti'
#  'dock workerparttim conway freight'
#  'account receiv collect clerk accountemp'
#  'concierg spectrum retir commun llc' 'part time organiz guru officeteam'
#  'front desk coordin local medic group officeteam'
#  'payrol administr accountemp'
#  'rn regist nurs need bayada home health care'
#  'rn 4east neurolog pt day 7a7p cathol health initi'
#  'cosmet sale consult lancom herberg' 'career fair'
#  'human resourc recruit officeteam'
#  'matern technician 08fte day swedish health'
#  'secur offic part timemidnight hss inc' 'per diem dietari aid pinnacl'
#  'spanish speak servic specialist officeteam'
#  'transport secur offic mot transport secur administr'
#  'entri level caregiv home health aid home instead senior care'
#  'med tech elmcroft senior live'
#  'mainten mechan kessler institut rehabilit'
#  'entri level sale market coordin full time career new year new opportun'
#  'temporari administr assist need asap officeteam'
#  'front desk brandicorp manag' 'nurs practition parttim geo group inc'
#  'project assist 5 posit officeteam' 'receptionist omnicar'
#  'wireless retail sale associ marketsourc'
#  'parttim gener offic clerk real estat compani officeteam'
#  'lpn licens practic nurs obgyn women health 3 daysweek medscrib inc'
#  'resp therapist reg barstow healthcar mgmt mso'
#  'offic assist custom servic receptionist'
#  'field support opportun unit state armi'
#  'custom servic advisor csa mister car wash'
#  'seek colleg graduat amaz opportuni officeteam'
#  'outbound custom servic repres officeteam'
#  'careerbuild account payabl opportun accountemp'
#  'firstchoic rn icu facil sjmh administr svc locat ann arbor mi saint joseph merci health system'
#  'home health aid livein caresouth' 'loan processor support accountemp'
#  'expand firm fill entri level posit train immedi open'
#  'sonograph obx pediatrix medic group' 'surgic scrub tech'
#  'cna signatur healthcar llc' 'cashier omaha town park'
#  'anim assist therapi specialist north spring behavior healthcar'
#  'retail sale associ cash america'
#  'call custom servic profession officeteam' 'util brightview senior live'
#  'parttim detail automot servic assist ford olath ford'
#  'rn clinic nurs ii per diem child adolesc psychiatri unit 5 neurosci unc health care'
#  'usa today strateg market internship va summer 2015 usa today'
#  'emi trust advisor 125 illinoi rd ft wayn club demonstr servic'
#  'nurs rn lpn life care center america' 'parttim hr manag'
#  'sale profession flexibl schedul part time bloomingdal aventura mall fl bloomingdal'
#  'logist clerk officeteam' 'account receiv opportun avail accountemp'
#  'dental receptionist parttimebilingu afternoon hour officeteam'
#  'inventori taker us dist 359 peabodi manorthshor rgi'
#  'entri level healthcar profession want caregiv opportun home instead senior care'
#  'carmax foundat internship carmax' 'mock juror'
#  'psychiatr technician nh human servic'
#  'chines research analyst opportun san francisco accountemp'
#  'store associ circl k midwest' 'teller coin teller'
#  'gym teacher red hill montessori academi'
#  'physic therapi technician agil health'
#  'medic payment poster innov physic therapi clini accountemp'
#  'clerk pa tag titl aaa mid atlant'
#  'di special servic brand ambassador rochest market club demonstr servic'
#  'hvac instructor vatterott educ center' 'regist nurs rn corizon'
#  'certifi nurs assist cna life care center america'
#  'night weekend nurs trach vent bayada home health care'
#  'retail sale manag assist manag full time sale part time sale tuxedo junction'
#  'wait staff erickson live' 'custom servic repres regu manag group'
#  'multipl custom servic opportun officeteam'
#  'medic offic manag psychiatr offic' 'servic technician invis fenc brand'
#  'cna willowbrook act retir life commun'
#  'meet new grad specialist officeteam robert half intl officeteam'
#  'dynam account clerk need accountemp'
#  'home depot product assembl advantag sale market'
#  'doctor assist officeteam' 'senior art director boss group'
#  'document scan specialist west de moin accountemp'
#  'mobil sale repres marketsourc'
#  'retail store sale associ part time albani ga ppg architectur coat'
#  'bar porter pool bar temp pt mgm resort intern'
#  'rc life enrich assist spectrum retir commun llc'
#  'physic therapi assist parttim american merci home care'
#  'offic assist munitemp municip staf solut'
#  'hour case manag franziska racker center'
#  'retail sale associ entri level manag sofa mart oak express bedroom express furnitur row'
#  'field consult subway' 'adjunct english instructor mildredelley'
#  'technolog sale specialist'
#  'health well famili nurs practition healthstat'
#  'clinton ct recruit event marrakech inc'
#  'licens practic nurs correct care solut' 'dock worker forward air inc'
#  'purchas accountemp'
#  'sale entri level sale market sale financi concept america'
#  'atlanta pt oral surgeon opportun et dental'
#  'driver warehous part time fi outdoor'
#  'merchant servic sale repres chi payment system'
#  'per diem home health occup therapist 140265 gentiva health servic inc'
#  'leas agent parttim raintre apart'
#  'occup therapi asst cota physic therapi chandler region medic center digniti health member'
#  'seek hr analyst tech compani officeteam' 'teller union save bank'
#  'teller parttim 20 hr mall america bankunit'
#  'teller 20 hr 3221 red river st well fargo'
#  'junior accountantbookkeep confidenti'
#  'therapeut support staff tss franklin famili servic'
#  'parttim cook elmcroft senior live'
#  'dietari aid autumn ridg rehabilit centr'
#  'mental health technician parttim 1st shift devereux'
#  'execut administr assist officeteam'
#  'season loss prevent secur guard newington nh fox run maci'
#  'copi print associ stapl'
#  'victim servic specialist 11614 mother drunk drive madd'
#  'rn lpn pediatr home care dickson citi pa bayada home health care'
#  'certifi nurs assist cna littl sister poor'
#  'slp speech languag pathologist home health parttim bayada home health care'
#  'parttim even receptionist howard wilson chrysler jeep dodg'
#  'custom servic represnt officeteam'
#  'secur dispatch temp marketplac univers protect servic'
#  'warehous associ recruit solut'
#  'psychiatri posit correct facil corizon health'
#  'temporari attorney document review hire counsel'
#  'retail sale associ fulltim marketsourc'
#  'medic aid evangel lutheran good samaritan societi'
#  'temporari product associ pridestaff'
#  'seek skill custom servic repres officeteam'
#  'switchboard oper swedish health'
#  'certifi nurs assist cna 7 7 pm caresouth'
#  'teller part time talmer bank trust'
#  'certifi nurs assist cna overnight 7 pm 7 caresouth'
#  'clerk ogden region medic center parallon' 'properti account accountemp'
#  'machin oper product darrel walker workforc system'
#  'execut assist part time kelli servic' 'behavior health tech meadow'
#  'rn prn care manag home health west palm beach fl humana'
#  'custom servic rep officeteam' 'administr assist nonprofit officeteam'
#  'custom servic repres reput compani officeteam' 'rn commun health system'
#  'clinic laboratori scientist laboratori christu spohn shorelin prn christu health'
#  'custom servic bdc rep part time counti line nissan'
#  'searshom solut advisor sear roebuck co'
#  'part time meat clerk oakpoint center harri teeter'
#  'pit clerk pt mgm resort intern'
#  'automot internet sale bdc repres bdc sale carl black automot'
#  'entri level financi analyst accountemp'
#  'school day camp counselor ii ymca greenvil'
#  '3 4 wknd staff nurse7p730a3 southlankenau medic ce main line health system'
#  'test driver relianc one inc'
#  'document review attorney thai plant moran staf'
#  'season med surg rn night shift 7p730a commun health system'
#  'quickbook guru accountemp' 'molecular sale consult msc oncal llc'
#  'snack bar attend new point rv resort'
#  'immedi need bilingu japanes speaker officeteam'
#  'engin intern summer 2015012 kearfott corpor'
#  'healthcar account specialist accountemp'
#  'occup therapist prn hcaeast florida'
#  'hha spinal cord injuri need kailua bayada home health care'
#  'regist nurs medicalsurg swedish health'
#  'caregiv hha cna certifi nurs aid homewel senior care greenvil'
#  'teller parttim brewerton keybank'
#  'temporari social servic program coordin salvat armi stuart'
#  'handbag sell specialist part time bloomingdal chevi chase md bloomingdal'
#  'unarm hospit secur' 'butler brandywin senior live'
#  'stabl account manag opportun manufactur officeteam'
#  'regist nurs rn part time per diem nurs pediatr icu parallon workforc solut'
#  'entri level recruit officeteam'
#  'staff regist nurs psychiatri per diem variabl shift swedish health'
#  'deliveri driver part time 20th street thoma napa'
#  'driver cdl dock part time yrc freight'
#  'veterinari technician windcrest anim hospit'
#  'regist nurs wadsworth point' 'financi analyst healthcar accountemp'
#  'admiss market director revera'
#  'technic support help desk northpoint personnel'
#  'clerk servic corpor intern' 'home health aid star multi care servic'
#  'part time hostler 30 hoursweek staffmark'
#  'account offic admin confidenti chester counti pa landscap architectur firm'
#  'offic manag accountemp'
#  'senior csr teller court main bc full time fifth third bank'
#  'season loss prevent secur guard dalla tx dalla galleria maci'
#  'snack bar attend american golf corpor'
#  'unarm secur offic us secur associ'
#  'line cook crown plaza independ own oper'
#  'kitchen manag job detail artesian hotel casino tradit spirit']

# %%
def recommend(title):
    idx=job_df[job_df['Title']==title].index[0]
    idx=job_df.index.get_loc(idx)
    distances = sorted(list(enumerate(similarity[idx])),key=lambda x:x[1],reverse=True)[1:21]
     
    print(distances)
    jobs=[]
    for i in distances:
        job_info = {
            'Title': job_df.iloc[i[0]]['Title'],
            'Position': job_df.iloc[i[0]]['Position'],
            'Company': job_df.iloc[i[0]]['Company'],
            'Status': job_df.iloc[i[0]]['Status'],
            'Job Description': job_df.iloc[i[0]]['Job.Description']
        }
        #print(job_info)
        jobs.append(job_info)
    
    return jobs

# %%
recommend('account manag chi payment system')
# Out:
# [(383, np.float64(0.9496440937426611)), (872, np.float64(0.5352879938074053)), (501, np.float64(0.23168821254943936)), (415, np.float64(0.20482781816723114)), (874, np.float64(0.19311706608136958)), (359, np.float64(0.1880466780236648)), (594, np.float64(0.18200611088429028)), (821, np.float64(0.18131232089211247)), (764, np.float64(0.16486071558176807)), (712, np.float64(0.13658657095934923)), (533, np.float64(0.1306285106559144)), (448, np.float64(0.12690715373513498)), (424, np.float64(0.12166897081870358)), (29, np.float64(0.12157788337075755)), (173, np.float64(0.12157788337075755)), (175, np.float64(0.12157788337075755)), (277, np.float64(0.12157788337075755)), (314, np.float64(0.12157788337075755)), (328, np.float64(0.12157788337075755)), (414, np.float64(0.12157788337075755))]
# [{'Title': 'entri level sale repres chi payment system',
#   'Position': 'entri level sale repres',
#   'Company': 'CHI Payment Systems',
#   'Status': 'open',
#   'Job Description': 'yoursquor energet motiv hardwork look prosper occup chi payment system exactli look employ career chi payment system make dream own busi earn sixfigur incom realiti nbsp nbsp chi payment system util independ sale agent across unit state set new exist busi abil accept credit card transactionsnbsp juggernaut merchant servic industri enabl agent offer competit rate fee prospect merchantsnbsp also provid superior level support valu busi set merchant servicesnbspnbsp chi payment system compris season manag team two decad experi merchant servic industrynbsp dedic train support motiv sale agentsnbsp arm agent skill techniqu need domin competitionnbsp also incentiv agent extrem aggress commiss structur includ bonus addit residu payout account set success success independ agent recruit depart open fromnbsp7am 6 pm pacif time monday fridaynbsp look forward speak nbsp nbsp'},
#  {'Title': 'merchant servic sale repres chi payment system',
#   'Position': 'merchant servic sale repres',
#   'Company': 'CHI Payment Systems',
#   'Status': 'open',
#   'Job Description': 'chi payment system lead merchant servic provid outsid sale repres opportun availablenbsp outsid sale representativenbsp1099 employe run busi make hour hold fulltim roll use outsid sale repres opportun earn extra incom chi payment system excit outsid sale repres opportun chi payment systemsnbspoutsid sale repres across unit state set new exist busi abil accept credit card transact nbsp juggernaut merchant servic industri enabl sale repres offer competit rate fee prospect merchant nbsp also provid superior level support valu busi set merchant servicesnbsp chi payment system provid outsid sale repres toptier train continu support sale director teach close merchant enhanc industri knowledg grow network give everyth need success sale repres truli awesom thing program run busi boss make hour extrem profitablenbsp outsid sale repres also receiv 250 everi activ merchant sign receiv addit 150 first account extra 100 second account hit 8 merchant account receiv addit 600 hit 20 merchant account receiv addit 2500 receiv volum bonus receiv residu check'},
#  {'Title': 'enrol agent immedi opportun officeteam',
#   'Position': 'enrol agent immedi opportun',
#   'Company': 'OfficeTeam',
#   'Status': 'open',
#   'Job Description': 'ref 00920106815classif custom servicecompens 1425 1650 per houron nation largest softwar provid tax industri seek enrol agent enrol agent respons field question client relat file tax softwar addit enrol agent assist train schedul new hire temporari staff tax season'},
#  {'Title': 'leas agent',
#   'Position': 'leas agent',
#   'Company': '',
#   'Status': 'open',
#   'Job Description': 'leas agent upscal apart commun look hire reliabl friendli outgo leas agent nbspcandid expect work everi weekend bullnbspnbspnbspnbspmaintain profession atmospher interact prospect bullnbspnbspnbspnbspschedul movein coordin necessari document bullnbspnbspnbspnbspcompar advertis price competitor bullnbspnbspnbspnbspassist manag budget forecast nbsp'},
#  {'Title': 'leas agent parttim raintre apart',
#   'Position': 'leas agent parttim',
#   'Company': 'Raintree Apartments',
#   'Status': 'open',
#   'Job Description': 'strong leas agent need lexington ky properti leas agent assist properti manag effect manag assign commun respons includ time collect deposit rental incom leas apart aspect prepar weekli leas report account report duti may assign'},
#  {'Title': 'account manag sale',
#   'Position': 'account manag sale',
#   'Company': '',
#   'Status': 'open',
#   'Job Description': 'account manag sale encor payment solut leader payment process industri offer custom latest technolog includ tablet smartphon solut combin strong commit custom servic current expand sale forc nationwid seek experienc profession skill give profession honest ethic present local busi mani industri regul chang technolog process solut expand everi day truli amaz time part ground floor opportun busi develop fanat skill succeed motiv make happen hardwork selfmotiv readi reap reward job well done passion custom servic excel innov technolog drive capit opportun serv creativ consult client throughout territori entri level associ experi alreadi belt abil combin market customerfocus sell strategi allow maxim busi opportun everi turn perk posit account manag sale support busi develop effort outstand compens perform incent includ preset appoint encor market team aggress compens plan bonu incent comprehens train reimburs full support staff daili sell activ opportun career advanc basic medic dental amp vision coverag bonu program latest greatest payment secur product help succeed'},
#  {'Title': 'call center agent need even weekend dialamerica inc',
#   'Position': 'call center agent need even weekend',
#   'Company': 'DialAmerica, Inc.',
#   'Status': 'open',
#   'Job Description': 'current hire custom servic repres servic new exist custom account phone industrylead client join famili talent repres custom servic skill sound better earn top dollar perform feel good repres nation known compani experienc profession alway welcom entrylevel candid encourag appli small train class oneonon coach proven strategi guarante success offer flexibl even schedul 500pm 1000pm monday thru thursday 900am 200pm saturdaylimit postion avail'},
#  {'Title': 'medic payment poster innov physic therapi clini accountemp',
#   'Position': 'medic payment poster innov physic therapi clini',
#   'Company': 'Accountemps',
#   'Status': 'open',
#   'Job Description': 'ref id00216000393classificationaccount medicalcompensation1600 1900 per hourmed payment poster need work innov physic therapi clinic scottsdal locat job summari medic payment poster perform relat function regard applic payment insur carrier well patient medic payment poster duti respons 1 daili electron manual post payment insur carrier comput system 2 daili post patient payment bank lockbox comput system 3 reconcil balanc insur payment bank deposit 4 post contractu adjust patient account transfer copay deduct andor coinsur amount patient respons 5 report differ payment vs contract rate base explan benefit 6 research submit refund request insur compani patient requir document 7 rout insur denial insur account receiv team resubmiss appeal 8 problem solv identifi resolv insur payment discrep 9 assist claim resubmiss project necessari 10 continu medic educ stay abreast current issu trend chang law regul govern medic bill 11 provid support member bill depart team need 12 perform duti assign'},
#  {'Title': 'account payabl clerk accountemp',
#   'Position': 'account payabl clerk',
#   'Company': 'Accountemps',
#   'Status': 'open',
#   'Job Description': 'ref id00720121991classificationaccount payabl clerkcompensation1350 1600 per hourour client fairfield counti seek account payabl clerk one year experi respons includ process invoic payment wire ensur invoic proper level author payment complianc compani corpor invoic approv polici proactiv work depart obtain requir approv necessari determin proper cost center alloc correct gener ledger account determin payment schedul ensur prompt payment invoic provid payment statu detail request immedi consider pleas submit resum accountempscom call 2033243399'},
#  {'Title': 'commerci account manag orkin hirel',
#   'Position': 'commerci account manag orkin',
#   'Company': 'HireLive',
#   'Status': 'open',
#   'Job Description': '  orkin pest control nation busi servic provid seek talent male femal expand busi busi salesnbsp found 1901 one lead commerci servic provid unit statesnbsp provid accur comprehens effici pest manag servic hospit food servic industri retail institut marketsnbsp orkin rate train magazin american societi train develop one 125 best train companiesnbsp know trainnbsp posit ideal candid want part rock solid compani provid valuabl servic customersnbsp posit avail commerci account manag posit descript nbspthi posit excel career opportun experienc outsid salespersonnbsp account manag develop new busi custom assign areanbsp report district sale manag account manag abl selfgener new lead abil close new commerci busi outsid sale environmentnbsp account manag must also abl develop make present key decis makersnbsp account manag must abil quickli comprehend technic featur servicesnbsp previou commerci prospect outsid sale experi busi busi environ mustnbsp orkin provid top train new rep rate train magazin one 125 top train compani past 8 consecut year posit requirementsnbsp 3 plu year outsid sale experi busi busi set strong commun interperson skill excel followup organiz skill abil self start work independ clean drive recorddepend transport abil pass crimin record check drug screen physic exam compens benefit salari commiss auto allow ga allow upon obtain sale goal compani vehicl earn presidentrsquo club medic dental vision insur nbsp401k plan life insur long amp short term disabl flexibl spend account special benefit program sick leav paid vacat holiday employe stock purchas plan discount compani servic scholarship program travel discount job referr bonu program meet hire manag april 9th dress success san diego north thursday april 9th 900am ndash 1230pm hyatt regenc 3777 la jolla villag drive san diego ca 92122 park 7 fix rate send resum attend click email resum bring 1015 resum dress busi profession free event job seeker wwwhirelivecom get social hirel facebook linkedin job opportun includ insid sale rep outsid sale rep account execut retail manag account manag insur sale custom servic technic sale sale manag pharmaceut sale telesal sale trainer merchandis mortgag broker financi planner rout sale retail sale retail manag human resourc much'},
#  {'Title': 'rental sale agent commiss base nation newark airport nationalalamo',
#   'Position': 'rental sale agent commiss base nation newark airport',
#   'Company': 'National/Alamo',
#   'Status': 'open',
#   'Job Description': 'get fast track reward career alamo rentacar compani commit qualiti innov custom satisfact employe developmentw multibilliondollar industri leader rapidli expand grow alamo rentacar excit career opportun made possibl far go realli fastpac peopl orient busi offer incred earn potenti performancebas promotionsour philosophi take care custom employe first know success follow compani employe nation brand alamo drive allianc excit opportun rental sale agent rental sale agent provid superior friendli effici transact time rental return use compani approv sale servic techniqu facilit rental process verif document necessari driver inform provid effici time rental return experi perform respons focu want need custom accord qualiti standard posit hourli plu commiss averag annual compens 35k 55k base perform use compani approv sale servic techniqu determin custom needsoff option product meet custom want needsprepar rental return document accur completelyqualifi custom use compani rental requir guidelinesprovid custom assist direct map local area inform appropri servic inform etcreview rental paramet custom ensur complet understand rate servic chargesensur return date time rental agreement accuratereview charg time vehicl returnprepar rental agreement folder requir informationansw phone assist custom friendli help prompt mannerassist custom effect resolv custom servic issuesassist coordin custom within queue minim wait time promot effici servic method requir equal opportun employ minoritieswomenveteransdisabledmust least 18 year oldmust minimum 2 year commiss incent base sale experiencemust valid driver licens 3 move violat andor atfault accid drive record within past 3 year drug alcohol relat convict drive record within past 5 year duidwimust author work unit state requir work author sponsorship compani posit futuremust will accept 925 hour plu commissionincent averag annual compens 35k 55k base performanceapart religi observ must avail work 40 hour week includ night weekend'},
#  {'Title': 'part time return agent indianapoli airport nationalalamo',
#   'Position': 'part time return agent indianapoli airport',
#   'Company': 'National/Alamo',
#   'Status': 'open',
#   'Job Description': 'get fast track reward career nation car rental alamo rent car team commit qualiti innov custom satisfact employe developmentw multibilliondollar industri leader rapidli expand grow nation alamo excit career opportun made possibl far go realli fastpac peopl orient busi offer incred earn potenti performancebas promotionsour philosophi take care custom employe first know success follow compani employe nation alamo excit opportun return agent return agent provid superior friendli effici servic aspect rental car process assist custom rental return process provid profession knowledg courteou servic accur complet transact perform respons focu need custom accord qualiti standard posit locat park garag indianapoli airport part time posit pay 1050hour plu incent opportun earn must abl work tue thur afternoon 200 pm 1000 pm 1hour break flexibl must avail least 800 pm greet custom use prescrib appropri dialogu arriv lotremind custom check person belong identifi item found vehicl unit number date time turn lost foundadvis review rental charg provid accur receipt customerprovid inform profession courteou manner regard transport airport termin thank custom use prescrib dialogueinquir servic satisfact document dissatisfactiondiscreetli check vehicl damag incom vehicl direct custom counter complet damageloss reportus proper statement determin vehicl return full tank gascomplet servic alert mechan bodi damag commun customersidentifi vehicl system hold turnback time mileag recal special lock verifi movement proper lot locationidentifi tag vehicl flag ground prevent mainten verifi movement proper lot locationkeep lot organ eas access traffic flowunderstand cdwemerald aislechoic process knowledg rentalreturn document fuel servic daysextra hourssurcharg option coveragesunderstand damag loss report report procedur equal opportun employ minoritieswomenveteransdisabledmust least 18 year agehigh school diploma ged requiredminimum 1 year experi handl custom servic functionsa minimum basic level experi understand pc microsoft offic product requiredmust author work unit state requir work author sponsorship compani posit futuremust abl work follow shiftschedul tue thur afternoon 200 pm 1000 pm 1hour break flexibl must avail least 800 pm must valid driver licens 2 move violat andor fault accid past 3 yearsno drug alcohol relat convict record past 5 year ie dui dwi'},
#  {'Title': 'medic account receiv specialist accountemp',
#   'Position': 'medic account receiv specialist',
#   'Company': 'Accountemps',
#   'Status': 'open',
#   'Job Description': 'ref id01060112842classificationaccount medicalcompensationdoew seek full time medic receptionist payment post specialist work alongsid dedic team health care provid casselberri fl strong applic must abl work independ multitask work well pressur excel written verbal skill comput savvi possess posit attitud job skillsrequir duti includ limit perform patient schedul function answer telephon screen forward call manag patient inform flow file maintain electron paper record perform payment post phone person reconcil patient account provid appropri account balanc inform medic terminolog prefer educ requir high school diploma requir degre healthcarerel field prefer'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'},
#  {'Title': 'sale repres sale associ entri level vector market',
#   'Position': 'sale repres sale associ entri level',
#   'Company': 'Vector Marketing',
#   'Status': 'open',
#   'Job Description': '  nbsp eager learn opportun whether look parttim fulltim work fit around schedul look sale posit feel good need make extra money vector market help nbsp parttim fulltim opportun temporari perman capac colleg student recent high school graduat individu need extra incom other previou experi need train believ sale repres train program effect anyon want success us nbsp thatrsquo unlik lot compani donrsquot requir previou work experi specif major degre nbsp member team clearcut direct take succeed yoursquol choic move among sever differ career option ndash includ parttim fulltim manag nbsp sale repres offer nbsp excel pay train ndash initi train get good start opportun ongo train need promot opportun base merit tenur flexibl schedul work around famili commit job internship vacat schedul choic ndash peopl work us arenrsquot limit singl locat move school famili memberrsquo job requir reloc reason easili transfer offic near new locat nbspnbsp nbsp entri level sale repres outsid sale nbsp nbsp nbsp job respons nbsp sale repres vector market present cutco new exist custom lowkey oneonon basi nbsp offer minimum base pay donrsquot feel pressur make sale instead get focu provid excel servic custom excel yoursquol opportun make base result nbsp entri level sale repres outsid sale'}]

# %%
import pickle
pickle.dump(job_df,open('df.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
job_df
# Out:
#       Status                                              Title  \
# 64119   open                     site director knowledg univers
# 35827   open                        administr assist officeteam
# 72100   open                   account manag chi payment system
# 46355   open  outsid wholesal sale rep parttim river front c...
# 34166   open  custom servic rep help peopl hear loss captioncal
# ...      ...                                                ...
# 66282   open  sale repres sale associ entri level vector market
# 39515   open                           staff account accountemp
# 69231   open                  unarm secur offic us secur associ
# 69618   open            line cook crown plaza independ own oper
# 6144    open  kitchen manag job detail artesian hotel casino...
#
#                                      Position  \
# 64119                           site director
# 35827                        administr assist
# 72100                           account manag
# 46355        outsid wholesal sale rep parttim
# 34166  custom servic rep help peopl hear loss
# ...                                       ...
# 66282     sale repres sale associ entri level
# 39515                           staff account
# 69231                       unarm secur offic
# 69618                               line cook
# 6144                 kitchen manag job detail
#
#                                                  Company  \
# 64119                                 Knowledge Universe
# 35827                                         OfficeTeam
# 72100                                CHI Payment Systems
# 46355                    River Front Chrysler Jeep Dodge
# 34166                                        CaptionCall
# ...                                                  ...
# 66282                                   Vector Marketing
# 39515                                        Accountemps
# 69231                             US Security Associates
# 69618       Crowne Plaza- Independently Owned & Operated
# 6144   The Artesian Hotel and Casino - Tradition Spirits
#
#                                          Job.Description  \
# 64119  job summari knowledg univers ku site director ...
# 35827  ref 03110118480classif secretaryadmin asstcomp...
# 72100  yoursquor energet motiv hardwork look prosper ...
# 46355  outsid wholesal sale rep job respons sale repr...
# 34166    captioncal commun assist imagin life without...
# ...                                                  ...
# 66282    nbsp eager learn opportun whether look partt...
# 39515  ref id02120107460classificationaccount staffco...
# 69231  direct supervis unarm secur offic respons patr...
# 69618  summari respons maintain set food product qual...
# 6144   posit descript provid overal leadership superv...
#
#                                               clean_text  \
# 64119  job summari knowledg univers ku site director ...
# 35827  ref 03110118480classif secretaryadmin asstcomp...
# 72100  yoursquor energet motiv hardwork look prosper ...
# 46355  outsid wholesal sale rep job respons sale repr...
# 34166    captioncal commun assist imagin life without...
# ...                                                  ...
# 66282    nbsp eager learn opportun whether look partt...
# 39515  ref id02120107460classificationaccount staffco...
# 69231  direct supervis unarm secur offic respons patr...
# 69618  summari respons maintain set food product qual...
# 6144   posit descript provid overal leadership superv...
#
#                                            combined_text
# 64119  site director knowledg univers site director K...
# 35827  administr assist officeteam administr assist O...
# 72100  account manag chi payment system account manag...
# 46355  outsid wholesal sale rep parttim river front c...
# 34166  custom servic rep help peopl hear loss caption...
# ...                                                  ...
# 66282  sale repres sale associ entri level vector mar...
# 39515  staff account accountemp staff account Account...
# 69231  unarm secur offic us secur associ unarm secur ...
# 69618  line cook crown plaza independ own oper line c...
# 6144   kitchen manag job detail artesian hotel casino...
#
# [1000 rows x 7 columns]
